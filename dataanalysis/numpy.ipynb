# %%
# !pip install numpy
# Out:
# ...
#    ---------------------------------------- 0.0/12.7 MB ? eta -:--:--
#    ---------------------------------------- 0.0/12.7 MB ? eta -:--:--
#    ---------------------------------------- 0.0/12.7 MB ? eta -:--:--
#     --------------------------------------- 0.3/12.7 MB ? eta -:--:--
#     --------------------------------------- 0.3/12.7 MB ? eta -:--:--
#    - -------------------------------------- 0.5/12.7 MB 493.7 kB/s eta 0:00:25
#    - -------------------------------------- 0.5/12.7 MB 493.7 kB/s eta 0:00:25
#    -- ------------------------------------- 0.8/12.7 MB 588.4 kB/s eta 0:00:21
#    --- ------------------------------------ 1.0/12.7 MB 699.0 kB/s eta 0:00:17
#    ---- ----------------------------------- 1.3/12.7 MB 780.2 kB/s eta 0:00:15
#    ---- ----------------------------------- 1.6/12.7 MB 856.1 kB/s eta 0:00:14
#    ------ --------------------------------- 2.1/12.7 MB 986.6 kB/s eta 0:00:11
# ...

# %%
import numpy as np

# %%
arr = np.array([1, 2, 3, 4, 5])
arr
# Out:
# array([1, 2, 3, 4, 5])
